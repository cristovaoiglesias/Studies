# %% [markdown]
# <a href="https://colab.research.google.com/github/cristovaoiglesias/Studies/blob/master/Optimizations.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <img src="WhatsApp Image 2020-08-28 at 23.45.53.jpeg">
# <img src="WhatsApp Image 2020-08-28 at 23.46.06.jpeg">
# <img src="WhatsApp Image 2020-08-28 at 23.46.19.jpeg">
# <img src="WhatsApp Image 2020-08-28 at 23.46.34.jpeg">
# <img src="WhatsApp Image 2020-08-28 at 23.47.04.jpeg">
# <img src="WhatsApp Image 2020-08-28 at 23.47.21.jpeg">

# %%
import numpy as np
from matplotlib import pyplot as plt
from sklearn import linear_model, datasets
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt



plt.rcParams['figure.figsize'] = (12.0, 9.0)

n_samples = 1000
n_outliers = 50


X, Y, coef = datasets.make_regression(n_samples=n_samples, n_features=1,
                                      n_informative=1, noise=15,
                                      coef=True, random_state=0)

data = pd.DataFrame(data= np.c_[X, Y])
X = data.iloc[:, 0]
Y = data.iloc[:, 1]

plt.scatter(X, Y)
plt.show()


# Building the model
m = 0
b = 0

L = 0.003  # The learning Rate
epochs = 1100  # The number of iterations to perform gradient descent

n = float(len(X)) # Number of elements in X

b_values=[]
m_values=[]
error_values=[]

# Performing Gradient Descent 
for i in range(epochs): 
    Y_pred = m*X + b  # The current predicted value of Y
    error = Y - Y_pred
    Dm = (-2/n) * sum(X * (error))  # Derivative wrt m
    Db = (-2/n) * sum(error)  # Derivative wrt c
    m = m - L * Dm  # Update m
    b = b - L * Db  # Update c

    b_values.append(b)
    m_values.append(m)
    error_values.append(sum(error*error)/n) 
    error=sum(error*error)/n

    if (i%50==0):
      print("epochs",i)
      Y_pred = m*X + b
      plt.scatter(X, Y) 
      plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
      plt.show()



print("m:",m,"b:",b, "error:",error)

Y_pred = m*X + b
plt.scatter(X, Y) 
plt.plot([min(X), max(X)], [min(Y_pred), max(Y_pred)], color='red')  # regression line
plt.show()


fig = plt.figure()
ax = fig.add_subplot(111, projection='3d')

y=b_values
x=m_values
z=error_values
ax.scatter(x, y, z, c='r', marker='o')
ax.set_xlabel('m Label')
ax.set_ylabel('b Label')
ax.set_zlabel('Z Erro')

plt.show()
# Out:
# epochs 0
# epochs 50
# epochs 100
# epochs 150
# epochs 200
# epochs 250
# epochs 300
# epochs 350
# epochs 400
# epochs 450
# epochs 500
# epochs 550
# epochs 600
# epochs 650
# epochs 700
# epochs 750
# epochs 800
# epochs 850
# epochs 900
# epochs 950
# epochs 1000
# epochs 1050
# m: 81.96794895186166 b: 0.3514534634293605 error: 221.5120061296899

# %% [markdown]
# References:
#
# https://www.kaggle.com/residentmario/gradient-descent-with-linear-regression
#
# https://towardsdatascience.com/step-by-step-tutorial-on-linear-regression-with-stochastic-gradient-descent-1d35b088a843
#
# https://towardsdatascience.com/understanding-the-mathematics-behind-gradient-descent-dde5dc9be06e
#
#
# Goodfellow, Ian, et al. Deep learning. Vol. 1. Cambridge: MIT press, 2016.
#
# Deisenroth, Marc Peter, A. Aldo Faisal, and Cheng Soon Ong. Mathematics for machine learning. Cambridge University Press, 2020.
