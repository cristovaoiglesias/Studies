# %% [markdown]
# I think the state of the art in image modification is stable diffusion models.
#
#
# tasks
# - image modification or inpainting
# - image2image
#
# https://stability.ai/stable-image
#
#
# Tutorials
#
# https://huggingface.co/learn/cookbook/en/multimodal_rag_using_document_retrieval_and_vlms#2-load-dataset-
#
# https://github.com/OpenBMB/VisRAG
#
# https://medium.com/@manaranjanp/revolutionizing-rag-systems-chatting-with-complex-documents-using-vision-language-models-c8896a55bc31
#
# https://arxiv.org/html/2406.19150v1
#
# https://medium.com/@manaranjanp/revolutionizing-rag-systems-chatting-with-complex-documents-using-vision-language-models-c8896a55bc31
#
# https://encord.com/blog/vision-language-models-guide
#
# https://replicate.com/docs/guides/stable-diffusion/inpainting
#
# https://www.datacamp.com/tutorial/fine-tuning-stable-diffusion-xl-with-dreambooth-and-lora
#
# https://huggingface.co/learn/diffusion-course/en/unit3/1
#
# https://replicate.com/docs/guides/stable-diffusion/inpainting
#
# https://huggingface.co/docs/diffusers/v0.7.0/en/using-diffusers/inpaint
#
# https://huggingface.co/blog/controlnet
#
# https://machinelearningmastery.com/inpainting-and-outpainting-with-stable-diffusion/
#
# https://stable-diffusion-art.com/controlnet/
#
# https://github.com/CompVis/stable-diffusion
#
# https://github.com/AUTOMATIC1111/stable-diffusion-webui
#
#
# inpainting without webUI
# https://github.com/mix1009/sdwebuiapi
#
# https://huggingface.co/docs/diffusers/en/using-diffusers/inpaint
#
# https://www.koyeb.com/tutorials/use-stable-diffusion-and-pytorch-to-build-an-image-inpainting-service
#
# https://huggingface.co/blog/controlnet
#
# https://huggingface.co/docs/diffusers/v0.7.0/en/using-diffusers/inpaint
#
# youtube
#
# https://www.youtube.com/watch?v=v89kB4OScOA
#
# https://www.youtube.com/watch?v=eh1LOS7TFZ8
